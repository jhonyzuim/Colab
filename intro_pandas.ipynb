# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (1.1.4)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.6/dist-packages (from pandas) (1.18.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
import pandas as pd

# %%
#variaveis
lista_altura = [1.80, 1.78, 1.89]
lista_sexo = ['f', 'f', 'm']
lista_peso = [70, 80, 90]
#criando DataFranme
df = pd.DataFrame(lista_altura, columns=['altura'])
#dicionario entre chaves {}
df = pd.DataFrame({'altura':lista_altura, 'sexo':lista_sexo, 'peso':lista_peso})
#printar resultado
df
# Out:
#    altura sexo  peso
# 0    1.80    f    70
# 1    1.78    f    80
# 2    1.89    m    90

# %%
df.describe()
# Out:
#          altura  peso
# count  3.000000   3.0
# mean   1.823333  80.0
# std    0.058595  10.0
# min    1.780000  70.0
# 25%    1.790000  75.0
# 50%    1.800000  80.0
# 75%    1.845000  85.0
# max    1.890000  90.0

# %%
df.describe(include='all')
# Out:
#           altura sexo  peso
# count   3.000000    3   3.0
# unique       NaN    2   NaN
# top          NaN    f   NaN
# freq         NaN    2   NaN
# mean    1.823333  NaN  80.0
# std     0.058595  NaN  10.0
# min     1.780000  NaN  70.0
# 25%     1.790000  NaN  75.0
# 50%     1.800000  NaN  80.0
# 75%     1.845000  NaN  85.0
# max     1.890000  NaN  90.0

# %%
media = df['altura'].mean()
media
# Out:
# 1.8233333333333333

# %%
mediana =df.altura.median()
mediana
# Out:
# 1.8

# %%
moda = df.sexo.mode()
moda
# Out:
# 0    f
# dtype: object

# %%
percentis = df.altura.quantile([0.1, 0.25, 0.5, 0.7, 0.75])
percentis
# Out:
# 0.10    1.784
# 0.25    1.790
# 0.50    1.800
# 0.70    1.836
# 0.75    1.845
# Name: altura, dtype: float64

# %%
percentis.values
# Out:
# array([1.784, 1.79 , 1.8  , 1.836, 1.845])

# %%
percentis.values[2]
# Out:
# 1.8

# %%
import pandas as pd
#caminho onde está o arquivo python sempre barra para direita
c = '/content/drive/MyDrive/res/database/data/AC/DNAC2017.csv'

sinasc = pd.read_csv(c, dtype=str)

sinasc
# Out:
#       contador ORIGEM CODESTAB  ... TPROBSON PARIDADE KOTELCHUCK
# 0            1      1  2515768  ...       05        1          2
# 1            2      1  2516047  ...       05        1          3
# 2            3      1  5618347  ...       03        1          2
# 3            4      1  5618347  ...       02        0          5
# 4            5      1  5618347  ...       03        1          2
# ...        ...    ...      ...  ...      ...      ...        ...
# 16353    16354      1  2012499  ...       03        1          2
# 16354    16355      1  2151871  ...       05        1          5
# 16355    16356      1  2078791  ...       05        1          5
# 16356    16357      1  0010537  ...       01        0          5
# 16357    16358      1  0010510  ...       03        1          2
#
# [16358 rows x 61 columns]

# %%
sinasc.shape
# Out:
# (16358, 61)

# %%
sinasc.head(5)
# Out:
#   contador ORIGEM CODESTAB CODMUNNASC  ... CODPAISRES TPROBSON PARIDADE KOTELCHUCK
# 0        1      1  2515768     110010  ...        NaN       05        1          2
# 1        2      1  2516047     110018  ...        NaN       05        1          3
# 2        3      1  5618347     110020  ...        NaN       03        1          2
# 3        4      1  5618347     110020  ...        NaN       02        0          5
# 4        5      1  5618347     110020  ...        NaN       03        1          2
#
# [5 rows x 61 columns]

# %%
#transformar dados quantitativos
print(f'Tipo antes: {sinasc.PESO.dtypes}')
sinasc.PESO = pd.to_numeric(sinasc.PESO)
print(f'Tipo depois: {sinasc.PESO.dtypes}')
# Out:
# Tipo antes: object
# Tipo depois: float64

# %%
sinasc.IDADEMAE = pd.to_numeric(sinasc.IDADEMAE).astype(pd.Int64Dtype())
sinasc.IDADEMAE.dtypes
# Out:
# Int64Dtype()

# %%
sinasc.IDADEPAI = pd.to_numeric(sinasc.IDADEPAI).astype(pd.Int64Dtype())
sinasc.QTDFILVIVO = pd.to_numeric(sinasc.QTDFILVIVO).astype(pd.Int64Dtype())
sinasc.QTDFILMORT = pd.to_numeric(sinasc.QTDFILMORT).astype(pd.Int64Dtype())
sinasc.APGAR1 = pd.to_numeric(sinasc.APGAR1).astype(pd.Int64Dtype())
sinasc.APGAR5 = pd.to_numeric(sinasc.APGAR5).astype(pd.Int64Dtype())
sinasc.SEMAGESTAC = pd.to_numeric(sinasc.SEMAGESTAC).astype(pd.Int64Dtype())
sinasc.CONSPRENAT = pd.to_numeric(sinasc.CONSPRENAT).astype(pd.Int64Dtype())
sinasc.SERIESCMAE = pd.to_numeric(sinasc.SERIESCMAE).astype(pd.Int64Dtype())
sinasc.QTDPARTCES = pd.to_numeric(sinasc.QTDPARTCES).astype(pd.Int64Dtype())
sinasc.QTDPARTNOR = pd.to_numeric(sinasc.QTDPARTNOR).astype(pd.Int64Dtype())
sinasc.QTDGESTANT = pd.to_numeric(sinasc.QTDGESTANT).astype(pd.Int64Dtype())

# %%
sinasc.head(5)
# Out:
#   contador ORIGEM CODESTAB CODMUNNASC  ... CODPAISRES  TPROBSON PARIDADE KOTELCHUCK
# 0        1      1  2515768     110010  ...        NaN        05        1          2
# 1        2      1  2516047     110018  ...        NaN        05        1          3
# 2        3      1  5618347     110020  ...        NaN        03        1          2
# 3        4      1  5618347     110020  ...        NaN        02        0          5
# 4        5      1  5618347     110020  ...        NaN        03        1          2
#
# [5 rows x 61 columns]

# %%
sinasc[['IDADEMAE', 'IDADEPAI']]
# Out:
#        IDADEMAE  IDADEPAI
# 0            22        42
# 1            30        28
# 2            26      <NA>
# 3            28        22
# 4            22        28
# ...         ...       ...
# 16353        38      <NA>
# 16354        29        36
# 16355        26        33
# 16356        30      <NA>
# 16357        39      <NA>
#
# [16358 rows x 2 columns]

# %%
sinasc.dtypes
# Out:
# contador      object
# ORIGEM        object
# CODESTAB      object
# CODMUNNASC    object
# LOCNASC       object
#                ...
# STDNNOVA      object
# CODPAISRES    object
# TPROBSON      object
# PARIDADE      object
# KOTELCHUCK    object
# Length: 61, dtype: object

# %%
sinasc.columns
# Out:
# Index(['contador', 'ORIGEM', 'CODESTAB', 'CODMUNNASC', 'LOCNASC', 'IDADEMAE',
#        'ESTCIVMAE', 'ESCMAE', 'CODOCUPMAE', 'QTDFILVIVO', 'QTDFILMORT',
#        'CODMUNRES', 'GESTACAO', 'GRAVIDEZ', 'PARTO', 'CONSULTAS', 'DTNASC',
#        'HORANASC', 'SEXO', 'APGAR1', 'APGAR5', 'RACACOR', 'PESO', 'IDANOMAL',
#        'DTCADASTRO', 'CODANOMAL', 'NUMEROLOTE', 'VERSAOSIST', 'DTRECEBIM',
#        'DIFDATA', 'DTRECORIGA', 'NATURALMAE', 'CODMUNNATU', 'CODUFNATU',
#        'ESCMAE2010', 'SERIESCMAE', 'DTNASCMAE', 'RACACORMAE', 'QTDGESTANT',
#        'QTDPARTNOR', 'QTDPARTCES', 'IDADEPAI', 'DTULTMENST', 'SEMAGESTAC',
#        'TPMETESTIM', 'CONSPRENAT', 'MESPRENAT', 'TPAPRESENT', 'STTRABPART',
#        'STCESPARTO', 'TPNASCASSI', 'TPFUNCRESP', 'TPDOCRESP', 'DTDECLARAC',
#        'ESCMAEAGR1', 'STDNEPIDEM', 'STDNNOVA', 'CODPAISRES', 'TPROBSON',
#        'PARIDADE', 'KOTELCHUCK'],
#       dtype='object')

# %%
sinasc.shape
# Out:
# (16358, 61)

# %%
#quando buscar mais de uma coluna colocar 2 colchetes
sinasc[['contador', 'IDADEMAE']]
# Out:
#       contador  IDADEMAE
# 0            1        22
# 1            2        30
# 2            3        26
# 3            4        28
# 4            5        22
# ...        ...       ...
# 16353    16354        38
# 16354    16355        29
# 16355    16356        26
# 16356    16357        30
# 16357    16358        39
#
# [16358 rows x 2 columns]

# %%
#fazer filtro
sinasc[sinasc.ESTCIVMAE == '3']
# Out:
#       contador ORIGEM CODESTAB  ... TPROBSON PARIDADE  KOTELCHUCK
# 868        869      1  2000296  ...       03        1           5
# 944        945      1  2000296  ...       03        1           2
# 1283      1284      1  2000296  ...       05        1           5
# 2099      2100      1      NaN  ...       11        0           9
# 3438      3439      1  2000733  ...       07        1           2
# 4385      4386      1  2002078  ...       01        0           2
# 4908      4909      1  2000733  ...       11        1           2
# 6597      6598      1  2002078  ...       01        0           5
# 8387      8388      1  2001500  ...       03        1           9
# 8983      8984      1  2000296  ...       03        1           2
# 10150    10151      1  2000636  ...       10        1           2
# 12417    12418      1  2002078  ...       03        1           5
# 12728    12729      1  2000733  ...       10        1           2
# 14040    14041      1  2000733  ...       11        0           9
# 15422    15423      1  2000725  ...       03        1           2
#
# [15 rows x 61 columns]

# %%
#filtro que seja igual ao resultado de uma coluna & outra
sinasc[(sinasc.ESTCIVMAE == '3') & (sinasc.LOCNASC == '1')]
# Out:
#       contador ORIGEM CODESTAB  ... TPROBSON PARIDADE  KOTELCHUCK
# 868        869      1  2000296  ...       03        1           5
# 944        945      1  2000296  ...       03        1           2
# 1283      1284      1  2000296  ...       05        1           5
# 3438      3439      1  2000733  ...       07        1           2
# 4385      4386      1  2002078  ...       01        0           2
# 4908      4909      1  2000733  ...       11        1           2
# 6597      6598      1  2002078  ...       01        0           5
# 8387      8388      1  2001500  ...       03        1           9
# 8983      8984      1  2000296  ...       03        1           2
# 10150    10151      1  2000636  ...       10        1           2
# 12417    12418      1  2002078  ...       03        1           5
# 12728    12729      1  2000733  ...       10        1           2
# 14040    14041      1  2000733  ...       11        0           9
# 15422    15423      1  2000725  ...       03        1           2
#
# [14 rows x 61 columns]

# %%
#filtro que seja igual ao resultado de uma coluna ou outra
sinasc[(sinasc.ESTCIVMAE == '3') | (sinasc.LOCNASC == '1')]
# Out:
#       contador ORIGEM CODESTAB  ... TPROBSON PARIDADE  KOTELCHUCK
# 0            1      1  2515768  ...       05        1           2
# 1            2      1  2516047  ...       05        1           3
# 2            3      1  5618347  ...       03        1           2
# 3            4      1  5618347  ...       02        0           5
# 4            5      1  5618347  ...       03        1           2
# ...        ...    ...      ...  ...      ...      ...         ...
# 16353    16354      1  2012499  ...       03        1           2
# 16354    16355      1  2151871  ...       05        1           5
# 16355    16356      1  2078791  ...       05        1           5
# 16356    16357      1  0010537  ...       01        0           5
# 16357    16358      1  0010510  ...       03        1           2
#
# [15338 rows x 61 columns]

# %%
#filtro que seja diferente
sinasc[sinasc.ESTCIVMAE != '3']
# Out:
#       contador ORIGEM CODESTAB  ... TPROBSON PARIDADE  KOTELCHUCK
# 0            1      1  2515768  ...       05        1           2
# 1            2      1  2516047  ...       05        1           3
# 2            3      1  5618347  ...       03        1           2
# 3            4      1  5618347  ...       02        0           5
# 4            5      1  5618347  ...       03        1           2
# ...        ...    ...      ...  ...      ...      ...         ...
# 16353    16354      1  2012499  ...       03        1           2
# 16354    16355      1  2151871  ...       05        1           5
# 16355    16356      1  2078791  ...       05        1           5
# 16356    16357      1  0010537  ...       01        0           5
# 16357    16358      1  0010510  ...       03        1           2
#
# [16343 rows x 61 columns]

# %%
#filtro que seja maior ou =
sinasc[sinasc.ESTCIVMAE >= '3']
# Out:
#       contador ORIGEM CODESTAB  ... TPROBSON PARIDADE  KOTELCHUCK
# 8            9      1  5618347  ...       03        1           4
# 9           10      1  5618347  ...       01        0           5
# 12          13      1  5618347  ...       05        1           2
# 16          17      1  5701929  ...       11        1           9
# 17          18      1  5701929  ...       03        1           5
# ...        ...    ...      ...  ...      ...      ...         ...
# 16343    16344      1  2000393  ...       05        1           5
# 16344    16345      1  2000393  ...       10        1           2
# 16345    16346      1  2000393  ...       03        1           5
# 16348    16349      1  2000393  ...       03        1           5
# 16351    16352      1  2000393  ...       03        1           2
#
# [9526 rows x 61 columns]

# %%
#Qual é a media da idade mae, peso, apgar 1 min, apgar 5min, qtd filhos vivos e mortos?
sinasc[['PESO', 'IDADEMAE', 'APGAR1']].mean()
# Out:
# PESO        3240.746553
# IDADEMAE      25.116175
# APGAR1         8.255085
# dtype: float64
