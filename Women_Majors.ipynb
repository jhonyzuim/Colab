# %%
import pandas as pd
# %matplotlib inline
direct_link = 'http://www.randalolson.com/wp-content/uploads/percent-bachelors-degrees-women-usa.csv'
women_majors = pd.read_csv(direct_link)

print(women_majors.info())
women_majors.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Year                           42 non-null     int64
#  1   Agriculture                    42 non-null     float64
#  2   Architecture                   42 non-null     float64
#  3   Art and Performance            42 non-null     float64
#  4   Biology                        42 non-null     float64
#  5   Business                       42 non-null     float64
#  6   Communications and Journalism  42 non-null     float64
#  7   Computer Science               42 non-null     float64
#  8   Education                      42 non-null     float64
#  9   Engineering                    42 non-null     float64
#  10  English                        42 non-null     float64
#  11  Foreign Languages              42 non-null     float64
#  12  Health Professions             42 non-null     float64
#  13  Math and Statistics            42 non-null     float64
#  14  Physical Sciences              42 non-null     float64
#  15  Psychology                     42 non-null     float64
#  16  Public Administration          42 non-null     float64
#  17  Social Sciences and History    42 non-null     float64
# dtypes: float64(17), int64(1)
# memory usage: 6.0 KB
# None
#    Year  Agriculture  ...  Public Administration  Social Sciences and History
# 0  1970     4.229798  ...                   68.4                         36.8
# 1  1971     5.452797  ...                   65.5                         36.2
# 2  1972     7.420710  ...                   62.6                         36.1
# 3  1973     9.653602  ...                   64.3                         36.4
# 4  1974    14.074623  ...                   66.1                         37.3
#
# [5 rows x 18 columns]

# %%
# Abaixo de 20%
over_50 = women_majors.loc[0, (women_majors.loc[0]>50) & (women_majors.loc[0]<100)]
over_50
# Out:
# Art and Performance      59.700000
# Education                74.535328
# English                  65.570923
# Foreign Languages        73.800000
# Health Professions       77.100000
# Public Administration    68.400000
# Name: 0, dtype: float64

# %%
over_50_graph = women_majors.plot(x = 'Year', y = over_20.index, figsize = (12,8))
print('Type:', type(over_50_graph))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-51ec25d64130> in <module>()
# ----> 1 over_50_graph = women_majors.plot(x = 'Year', y = over_20.index, figsize = (12,8))
#       2 print('Type:', type(over_50_graph))
#
# NameError: name 'over_20' is not defined

# %%
# Importar styles do matplotlib
import matplotlib.style as style
style.available

# %%
style.use('tableau-colorblind10')
women_majors.plot(x = 'Year', y = over_50.index, figsize = (12,8))

# %%
# cores 
colors = [[0,0,0], [230/255,159/255,0], [86/255,180/255,233/255], [0,158/255,115/255], 
          [213/255,94/255,0], [0,114/255,178/255]]

# Criar um gráfico
fte_graph = women_majors.plot(x = 'Year', y = over_50.index, figsize = (12,8), color = colors, legend = False)

# %%
# cores 
colors = [[0,0,0], [230/255,159/255,0], [86/255,180/255,233/255], [0,158/255,115/255], 
          [213/255,94/255,0], [0,114/255,178/255]]

# Criar um gráfico
fte_graph = women_majors.plot(x = 'Year', y = over_50.index, figsize = (12,8), color = colors, legend = False)

# Mudar o tamanho das marcas
fte_graph.tick_params(axis = 'both', which = 'major', labelsize = 18)

# %%
# cores 
colors = [[0,0,0], [230/255,159/255,0], [86/255,180/255,233/255], [0,158/255,115/255], 
          [213/255,94/255,0], [0,114/255,178/255]]

# Criar um gráfico
fte_graph = women_majors.plot(x = 'Year', y = under_20.index, figsize = (12,8), color = colors, legend = False)

# Mudar o tamanho das marcas
fte_graph.tick_params(axis = 'both', which = 'major', labelsize = 18)

# Customizar as os textos das marcas para o eixo y
fte_graph.set_yticklabels(labels = [ '-10%  ','0%  ', '10%  ', '20%  ', '30%  ', '40%  ', '50%  ','60%  '])
print('The tick labels of the y-axis:', fte_graph.get_yticks()) # -10 e 60 não serão visíveis no gráfico

# %%
# cores 
colors = [[0,0,0], [230/255,159/255,0], [86/255,180/255,233/255], [0,158/255,115/255], 
          [213/255,94/255,0], [0,114/255,178/255]]

# Criar um gráfico
fte_graph = women_majors.plot(x = 'Year', y = under_20.index, figsize = (12,8), color = colors, legend = False)

# Mudar o tamanho das marcas
fte_graph.tick_params(axis = 'both', which = 'major', labelsize = 18)

# Customizar as os textos das marcas para o eixo y
fte_graph.set_yticklabels(labels = [ '50%  ','60%  '])
print('The tick labels of the y-axis:', fte_graph.get_yticks()) # -10 e 60 não serão visíveis no gráfico

# Engrossar a linha horizontal em y = 0
fte_graph.axhline(y = 0, color = 'black', linewidth = 1.3, alpha = .70)

# %%
# cores 
colors = [[0,0,0], [230/255,159/255,0], [86/255,180/255,233/255], [0,158/255,115/255], 
          [213/255,94/255,0], [0,114/255,178/255]]

# Criar um gráfico
fte_graph = women_majors.plot(x = 'Year', y = under_20.index, figsize = (12,8), color = colors, legend = False)

# Mudar o tamanho das marcas
fte_graph.tick_params(axis = 'both', which = 'major', labelsize = 18)

# Customizar as os textos das marcas para o eixo y
fte_graph.set_yticklabels(labels = [ '-10%  ','0%  ', '10%  ', '20%  ', '30%  ', '40%  ', '50%  ','60%  '])
print('The tick labels of the y-axis:', fte_graph.get_yticks()) # -10 e 60 não serão visíveis no gráfico

# Engrossar a linha horizontal em y = 0
fte_graph.axhline(y = 0, color = 'black', linewidth = 1.3, alpha = .70)

# Acrescentar uma linha extendendo o eixo X
fte_graph.set_xlim(left = 1969, right = 1970)

# %%
# cores 
colors = [[0,0,0], [230/255,159/255,0], [86/255,180/255,233/255], [0,158/255,115/255], 
          [213/255,94/255,0], [0,114/255,178/255]]

# Criar um gráfico
fte_graph = women_majors.plot(x = 'Year', y = under_20.index, figsize = (12,8), color = colors, legend = False)

# Mudar o tamanho das marcas
fte_graph.tick_params(axis = 'both', which = 'major', labelsize = 18)

# Customizar as os textos das marcas para o eixo y
fte_graph.set_yticklabels(labels = [ '-10%  ','0%  ', '10%  ', '20%  ', '30%  ', '40%  ', '50%  ','60%  '])
print('The tick labels of the y-axis:', fte_graph.get_yticks()) # -10 e 60 não serão visíveis no gráfico

# Engrossar a linha horizontal em y = 0
fte_graph.axhline(y = 0, color = 'black', linewidth = 1.3, alpha = .70)

# Acrescentar uma linha extendendo o eixo X
fte_graph.set_xlim(left = 1969, right = 2020)

# Tirar o título do eixo X
fte_graph.xaxis.label.set_visible(False)

# %%
# cores 
colors = [[0,0,0], [230/255,159/255,0], [86/255,180/255,233/255], [0,158/255,115/255], 
          [213/255,94/255,0], [0,114/255,178/255]]

# Criar um gráfico
fte_graph = women_majors.plot(x = 'Year', y = under_20.index, figsize = (12,8), color = colors, legend = False)

# Mudar o tamanho das marcas
fte_graph.tick_params(axis = 'both', which = 'major', labelsize = 18)

# Customizar as os textos das marcas para o eixo y
fte_graph.set_yticklabels(labels = [ '-10%  ','0%  ', '10%  ', '20%  ', '30%  ', '40%  ', '50%  ','60%  '])
print('The tick labels of the y-axis:', fte_graph.get_yticks()) # -10 e 60 não serão visíveis no gráfico

# Engrossar a linha horizontal em y = 0
fte_graph.axhline(y = 0, color = 'black', linewidth = 1.3, alpha = .70)

# Acrescentar uma linha extendendo o eixo X
fte_graph.set_xlim(left = 1969, right = 2020)

# Tirar o título do eixo X
fte_graph.xaxis.label.set_visible(False)

# Acrescentar assinatura
fte_graph.text(x = 1967.1, y = -6.5,
               s = '__________________________________________________________________________________________________________________________',
               color = 'grey', alpha = .70)
fte_graph.text(x = 1966.1, y = -9,
               s ='   Nome:                                                                                                          Fonte: National Center for Education Statistics   ', # copyright symbol ALT + 0169
               fontsize = 14, color = 'grey', alpha = .7)

# %%
# cores 
colors = [[0,0,0], [230/255,159/255,0], [86/255,180/255,233/255], [0,158/255,115/255], 
          [213/255,94/255,0], [0,114/255,178/255]]

# Criar um gráfico
fte_graph = women_majors.plot(x = 'Year', y = under_20.index, figsize = (12,8), color = colors, legend = False)

# Mudar o tamanho das marcas
fte_graph.tick_params(axis = 'both', which = 'major', labelsize = 18)

# Customizar as os textos das marcas para o eixo y
fte_graph.set_yticklabels(labels = [ '-10%  ','0%  ', '10%  ', '20%  ', '30%  ', '40%  ', '50%  ','60%  '])
print('The tick labels of the y-axis:', fte_graph.get_yticks()) # -10 e 60 não serão visíveis no gráfico

# Engrossar a linha horizontal em y = 0
fte_graph.axhline(y = 0, color = 'black', linewidth = 1.3, alpha = .70)

# Acrescentar uma linha extendendo o eixo X
fte_graph.set_xlim(left = 1969, right = 2020)

# Tirar o título do eixo X
fte_graph.xaxis.label.set_visible(False)

# Acrescentar assinatura
fte_graph.text(x = 1967.1, y = -6.5,
               s = '__________________________________________________________________________________________________________________________',
               color = 'grey', alpha = .70)
fte_graph.text(x = 1966.1, y = -9,
               s ='   Nome:                                                                                                          Fonte: National Center for Education Statistics   ', # copyright symbol ALT + 0169
               fontsize = 14, color = 'grey', alpha = .7)

# Acrescentar título e subtítulo
fte_graph.text(x = 1966.65, y = 62.7, s = "                  A diferença de gênero é transitória  ",
               fontsize = 26, weight = 'bold', alpha = .75)
fte_graph.text(x = 1966.65, y = 57, 
               s = '     Porcentegens de títulos conferidos a mulheres de 1970 a 2011 nos Estados Unidos \n               para casos extremos com porcentagens menores a 20% em 1970',
              fontsize = 19, alpha = .85)

# %%
# cores 
colors = [[0,0,0], [230/255,159/255,0], [86/255,180/255,233/255], [0,158/255,115/255], 
          [213/255,94/255,0], [0,114/255,178/255]]

# Criar um gráfico
fte_graph = women_majors.plot(x = 'Year', y = over_50.index, figsize = (12,8), color = colors, legend = False)

# Mudar o tamanho das marcas
fte_graph.tick_params(axis = 'both', which = 'major', labelsize = 18)

# Customizar as os textos das marcas para o eixo y
fte_graph.set_yticklabels(labels = [ '40%  ', '50%  ','60%  '])
print('The tick labels of the y-axis:', fte_graph.get_yticks()) # -10 e 60 não serão visíveis no gráfico

# Engrossar a linha horizontal em y = 0
fte_graph.axhline(y = 0, color = 'black', linewidth = 1.3, alpha = .70)

# Acrescentar uma linha extendendo o eixo X
fte_graph.set_xlim(left = 1969, right = 2020)

# Tirar o título do eixo X
fte_graph.xaxis.label.set_visible(False)

# Acrescentar assinatura
fte_graph.text(x = 1967.1, y = -6.5,
               s = '__________________________________________________________________________________________________________________________',
               color = 'grey', alpha = .70)
fte_graph.text(x = 1966.1, y = -9,
               s ='   Nome:                                                                                                          Fonte: National Center for Education Statistics   ', # copyright symbol ALT + 0169
               fontsize = 14, color = 'grey', alpha = .7)

# Acrescentar título e subtítulo
fte_graph.text(x = 1966.65, y = 62.7, s = "                  A diferença de gênero é transitória  ",
               fontsize = 26, weight = 'bold', alpha = .75)
fte_graph.text(x = 1966.65, y = 57, 
               s = '     Porcentegens de títulos conferidos a mulheres de 1970 a 2011 nos Estados Unidos \n               para casos extremos com porcentagens menores a 20% em 1970',
              fontsize = 19, alpha = .85)

# Add colored labels
fte_graph.text(x = 2012, y = 50, s = 'Agricultura', color = colors[0], weight = 'bold', rotation = 0, backgroundcolor = '#f0f0f0')

# %%
# cores 
colors = [[0,0,0], [230/255,159/255,0], [86/255,180/255,233/255], [0,158/255,115/255], 
          [213/255,94/255,0], [0,114/255,178/255]]

# Criar um gráfico
fte_graph = women_majors.plot(x = 'Year', y = over_50.index, figsize = (12,8), color = colors, legend = False)

# Mudar o tamanho das marcas
fte_graph.tick_params(axis = 'both', which = 'major', labelsize = 18)

# Customizar as os textos das marcas para o eixo y
fte_graph.set_yticklabels(labels = [  '40%  ', '50%  ','60%  ','70% ','80% ', '90% '])
print('The tick labels of the y-axis:', fte_graph.get_yticks()) # -10 e 60 não serão visíveis no gráfico

# Engrossar a linha horizontal em y = 0
fte_graph.axhline(y = 56, color = 'black', linewidth = 1.3, alpha = .70)

# Acrescentar uma linha extendendo o eixo X
fte_graph.set_xlim(left = 1969, right = 2020)

# Tirar o título do eixo X
fte_graph.xaxis.label.set_visible(False)

# Acrescentar assinatura
fte_graph.text(x = 1967.1, y = -6.5,
               s = '__________________________________________________________________________________________________________________________',
               color = 'grey', alpha = .70)
fte_graph.text(x = 1966.1, y = -9,
               s ='    Nome: Jhony Ferreira Cruz Zuim RA 1904451                                                                                              Fonte: National Center for Education Statistics   ', # copyright symbol ALT + 0169
               fontsize = 14, color = 'grey', alpha = .7)

# Acrescentar título e subtítulo
fte_graph.text(x = 1966.65, y = 98.7, s = "                  A diferença de gênero é transitória  ",
               fontsize = 26, weight = 'bold', alpha = .75)
fte_graph.text(x = 1966.65, y = 91, 
               s = '     Porcentegens de títulos conferidos a mulheres de 1970 a 2011 nos Estados Unidos \n               para casos extremos com porcentagens menores a 20% em 1970',
              fontsize = 19, alpha = .85)

# Add colored labels
fte_graph.text(x = 2012, y = 60.0, s = 'Art and Performance', color = colors[0], weight = 'bold', rotation = 0, backgroundcolor = '#f0f0f0')

fte_graph.text(x = 2012, y = 77.5, s = 'Education', color = colors[1], weight = 'bold', rotation = 0, backgroundcolor = '#f0f0f0')

fte_graph.text(x = 2012, y = 66.5, s = 'English', color = colors[2], weight = 'bold', rotation = 0, backgroundcolor = '#f0f0f0')

fte_graph.text(x = 2012, y = 70.8, s = 'Foreign Languages ', color = colors[3], weight = 'bold', rotation = 0,backgroundcolor = '#f0f0f0')

fte_graph.text(x = 2012, y = 85.1, s = 'Health Professions', color = colors[4], weight = 'bold',rotation=0, backgroundcolor = '#f0f0f0')

fte_graph.text(x = 2012, y = 81.4, s = 'Public Administration', color = colors[5], weight = 'bold', rotation = 0, backgroundcolor = '#f0f0f0')
# Out:
# The tick labels of the y-axis: [55. 60. 65. 70. 75. 80. 85. 90.]
# Text(2012, 81.4, 'Public Administration')

# %%
Art and Performance      59.700000
Education                74.535328
English                  65.570923
Foreign Languages        73.800000
Health Professions       77.100000
Public Administration    68.400000
