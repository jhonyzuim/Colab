# %%
x=10

# %%
type(x)
# Out:
# int

# %%
x = 5 + 3
y = x - 4
z = x * y
w = 6/3
a = 6//3
b = 5/3
d = 5//3
e = 5%3
f = 2**3
x, y, z, w, a, b, d, e, f
# Out:
# (8, 4, 32, 2.0, 2, 1.6666666666666667, 1, 2, 8)

# %%
x
# Out:
# 8

# %%
print(y)
# Out:
# 4

# %%
lista_inteiros = [1, 34, 25, 28]
lista_inteiros
# Out:
# [1, 34, 25, 28]

# %%
lista_strings = ["masculino", "feminono"]
lista_strings
# Out:
# ['masculino', 'feminono']

# %%
lista_composta = [lista_inteiros, lista_strings]
lista_composta
# Out:
# [[1, 34, 25, 28], ['masculino', 'feminono']]
