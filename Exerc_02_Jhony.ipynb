# %%
import pandas as pd
#caminho onde está o arquivo python sempre barra para direita
c = '/content/drive/MyDrive/res/database/data/SE/DNSE2017.csv'

sinasc = pd.read_csv(c, dtype=str)

sinasc
# Out:
#       contador ORIGEM CODESTAB  ... TPROBSON PARIDADE KOTELCHUCK
# 0            1      1  2415631  ...       05        1          9
# 1            2      1  2005050  ...       03        1          3
# 2            3      1  2005050  ...       11        0          5
# 3            4      1  2005026  ...       05        1          2
# 4            5      1  2722429  ...       03        1          2
# ...        ...    ...      ...  ...      ...      ...        ...
# 33862    33863      1  2115891  ...       10        1          5
# 33863    33864      1  3137163  ...       02        0          3
# 33864    33865      1  2755092  ...       04        1          5
# 33865    33866      1  2077574  ...       04        1          5
# 33866    33867      2  6901743  ...       03        1          5
#
# [33867 rows x 61 columns]

# %%
sinasc.IDADEMAE = pd.to_numeric(sinasc.IDADEMAE).astype(pd.Int64Dtype())
sinasc.QTDFILVIVO = pd.to_numeric(sinasc.QTDFILVIVO).astype(pd.Int64Dtype())
sinasc.QTDFILMORT = pd.to_numeric(sinasc.QTDFILMORT).astype(pd.Int64Dtype())
sinasc.APGAR1 = pd.to_numeric(sinasc.APGAR1).astype(pd.Int64Dtype())
sinasc.APGAR5 = pd.to_numeric(sinasc.APGAR5).astype(pd.Int64Dtype())
sinasc.PESO = pd.to_numeric(sinasc.PESO).astype(pd.Int64Dtype())
sinasc.ESTCIVMAE = pd.to_numeric(sinasc.ESTCIVMAE).astype(pd.Int64Dtype())
sinasc.QTDGESTANT = pd.to_numeric(sinasc.QTDGESTANT).astype(pd.Int64Dtype())
sinasc.QTDPARTNOR = pd.to_numeric(sinasc.QTDPARTNOR).astype(pd.Int64Dtype())
sinasc.QTDPARTCES = pd.to_numeric(sinasc.QTDPARTCES).astype(pd.Int64Dtype())
sinasc.SERIESCMAE = pd.to_numeric(sinasc.SERIESCMAE).astype(pd.Int64Dtype())
sinasc.CONSPRENAT = pd.to_numeric(sinasc.CONSPRENAT).astype(pd.Int64Dtype())
sinasc.SEMAGESTAC = pd.to_numeric(sinasc.SEMAGESTAC).astype(pd.Int64Dtype())
sinasc.IDADEPAI = pd.to_numeric(sinasc.IDADEPAI).astype(pd.Int64Dtype())

# %%
normal = sinasc[sinasc.PARTO =='1'][['IDADEMAE']]
cesaria = sinasc[sinasc.PARTO == '2'][['IDADEMAE']]

# %%
media_normal = normal.mean()
media_cesaria = cesaria.mean()
print(media_normal)
print(media_cesaria)
# Out:
# IDADEMAE    24.98357
# dtype: float64
# IDADEMAE    27.634743
# dtype: float64

# %%
dm_normal = normal.mad()
dm_cesaria = cesaria.mad()
print(dm_normal)
print(dm_cesaria)
# Out:
# IDADEMAE    5.576194
# dtype: float64
# IDADEMAE    5.642534
# dtype: float64

# %%
dp_normal = normal.std(ddof=0)
dp_cesaria = cesaria.std(ddof=0)
print(dp_normal)
print(dp_cesaria)
# Out:
# IDADEMAE    6.712947
# dtype: float64
# IDADEMAE    6.731974
# dtype: float64

# %%
q_normal = normal.quantile([0.25, 0.75]).values
q_cesaria = cesaria.quantile([0.25, 0.75]).values
iqr_normal = q_normal[1] - q_normal[0]
iqr_cesaria = q_cesaria[1] - q_cesaria[0]
iqr_normal, iqr_cesaria
# Out:
# (array([10.0], dtype=object), array([11.0], dtype=object))

# %%
cv_normal = dp_normal/media_normal
cv_cesaria = dp_cesaria/media_cesaria
print(cv_normal)
print(cv_cesaria)
# Out:
# IDADEMAE    0.268694
# dtype: float64
# IDADEMAE    0.243605
# dtype: float64

# %%
esc_0 = sinasc[sinasc.ESCMAE == '1']
esc_1_3 = sinasc[sinasc.ESCMAE == '2']
esc_4_7 = sinasc[sinasc.ESCMAE == '3']
esc_8_11 = sinasc[sinasc.ESCMAE == '4']
esc_12 = sinasc[sinasc.ESCMAE == '5']

# %%
sinasc['Filhos'] = sinasc.QTDFILVIVO + sinasc.QTDFILMORT
sinasc[['Filhos']]
# Out:
#        Filhos
# 0           1
# 1           4
# 2        <NA>
# 3        <NA>
# 4           4
# ...       ...
# 33862       1
# 33863       0
# 33864       1
# 33865       1
# 33866    <NA>
#
# [33867 rows x 1 columns]

# %%
esc_0 = sinasc[sinasc.ESCMAE == '1']
esc_1_3 = sinasc[sinasc.ESCMAE == '2']
esc_4_7 = sinasc[sinasc.ESCMAE == '3']
esc_8_11 = sinasc[sinasc.ESCMAE == '4']
esc_12 = sinasc[sinasc.ESCMAE == '5']

# %%
esc_12[['Filhos']]
# Out:
#        Filhos
# 5           1
# 21          0
# 24          1
# 38          1
# 39          0
# ...       ...
# 33858    <NA>
# 33859    <NA>
# 33860    <NA>
# 33862       1
# 33864       1
#
# [4969 rows x 1 columns]

# %%
print(esc_0.Filhos.mean())
print(esc_1_3.Filhos.mean())
print(esc_4_7.Filhos.mean())
print(esc_8_11.Filhos.mean())
print(esc_12.Filhos.mean())
# Out:
# 5.3105590062111805
# 3.5444630872483223
# 1.8571001941167686
# 1.0898249000413622
# 0.7098411297440423

# %%
print(esc_0.Filhos.std())
print(esc_1_3.Filhos.std())
print(esc_4_7.Filhos.std())
print(esc_8_11.Filhos.std())
print(esc_12.Filhos.std())
# Out:
# 3.1349561895757025
# 2.7203316734203207
# 1.9060303631334525
# 1.3222034129572715
# 0.9864946654291639
