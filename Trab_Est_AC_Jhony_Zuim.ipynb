# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('/content/drive/MyDrive/MBA/Data Visualization & Storytelling/Trabalho/base.xlsx')

# %%
df.head(3)
# Out:
#   Região  UF  ... Avaliação Reclamação Nota do Consumidor
# 0     NE  CE  ...         Não Avaliada                NaN
# 1     SE  SP  ...         Não Avaliada                NaN
# 2     NE  RN  ...         Não Avaliada                NaN
#
# [3 rows x 19 columns]

# %%
df_ac=df[df['UF']=='AC']

# %%
df_ac.head()
# Out:
#      Região  UF  ... Avaliação Reclamação Nota do Consumidor
# 349      N   AC  ...         Não Avaliada                NaN
# 1650     N   AC  ...         Não Avaliada                NaN
# 1915     N   AC  ...         Não Avaliada                NaN
# 2266     N   AC  ...         Não Avaliada                NaN
# 2334     N   AC  ...         Não Avaliada                NaN
#
# [5 rows x 19 columns]

# %%
df.shape
# Out:
# (338543, 19)

# %%
df_ac['Faixa Etária'].value_counts()
# Out:
# entre 31 a 40 anos    310
# entre 21 a 30 anos    266
# entre 41 a 50 anos    119
# entre 51 a 60 anos     72
# entre 61 a 70 anos     37
# até 20 anos            22
# mais de 70 anos        11
# Name: Faixa Etária, dtype: int64

# %%
df_ac['Faixa Etária'].hist()

# %%
df_ac['Nome Fantasia'].value_counts()
# Out:
# Oi Fixo                         80
# Vivo - Telefônica               50
# Latam Airlines (Tam)            48
# Energisa Acre (Eletroacre)      38
# Gol Linhas Aéreas               38
#                                 ..
# Google                           1
# Cartão Quero-Quero VerdeCard     1
# Banco Safra                      1
# Época Cosméticos                 1
# C&A                              1
# Name: Nome Fantasia, Length: 140, dtype: int64

# %%
df_ac['Grupo Problema'].value_counts()
# Out:
# Cobrança / Contestação    354
# Vício de Qualidade        156
# Atendimento / SAC         131
# Contrato / Oferta         112
# Informação                 52
# Entrega do Produto         27
# Saúde e Segurança           5
# Name: Grupo Problema, dtype: int64

# %%
df_prob=df_ac[df_ac['Grupo Problema']=='Cobrança / Contestação']

# %%
df_prob['Problema'].value_counts()
# Out:
# Cobrança indevida / abusiva para alterar ou cancelar o contrato                                           69
# Cobrança por serviço/produto não contratado / não reconhecido / não solicitado                            55
# Dificuldade / atraso na devolução de valores pagos / reembolso / retenção de valores                      54
# Cobrança de tarifas, taxas, valores não previstos / não informados                                        30
# Cobrança após cancelamento do serviço                                                                     22
# Cobrança em duplicidade / Cobrança referente a pagamento já efetuado                                      21
# Cobrança por serviço não fornecido/ em desacordo com a utilização / fora do prazo                         18
# Cobrança submetendo a ofensa, constrangimento ou ameaça                                                   11
# Renegociação / parcelamento de dívida                                                                     10
# ...

# %%
df_proc=df_ac[df_ac['Procurou Empresa']=='S']

# %%
df_proc['Faixa Etária'].value_counts()
# Out:
# entre 31 a 40 anos    260
# entre 21 a 30 anos    224
# entre 41 a 50 anos     95
# entre 51 a 60 anos     68
# entre 61 a 70 anos     31
# até 20 anos            15
# mais de 70 anos         8
# Name: Faixa Etária, dtype: int64

# %%
df_proc['Faixa Etária'].value_counts(normalize=True)
# Out:
# entre 31 a 40 anos    0.370899
# entre 21 a 30 anos    0.319544
# entre 41 a 50 anos    0.135521
# entre 51 a 60 anos    0.097004
# entre 61 a 70 anos    0.044223
# até 20 anos           0.021398
# mais de 70 anos       0.011412
# Name: Faixa Etária, dtype: float64

# %%
df_med=df_ac['Tempo Resposta'].mean()
df_med
# Out:
# 7.792223572296476

# %%
df_med=df_ac['Tempo Resposta'].mean()
df_med=df_ac['Tempo Resposta'].max()
df_medemp=df_ac[df_ac['Tempo Resposta'] == 16.0]
df_medemp['Nome Fantasia'].value_counts()
# Out:
# Energisa Acre (Eletroacre)    2
# Itaú Unibanco Consignado      1
# Oi Fixo                       1
# Banco Daycoval                1
# Name: Nome Fantasia, dtype: int64

# %%
df_ac['Nota do Consumidor'].value_counts()
# Out:
# 5.0    195
# 1.0    163
# 4.0     50
# 3.0     37
# 2.0     19
# Name: Nota do Consumidor, dtype: int64
