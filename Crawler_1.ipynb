# %%
#Importação de bibliotecas e módulos para o crawler e scraping

import requests # realizar requisições HTTP GET e POST
from requests.compat import urljoin # encontrar URL absoluta
from bs4 import BeautifulSoup # navegar e extrair conteúdo do HTML
import re # expressão regular
import os # acessar recursos do sistema operacional
import IPython # visualização de páginas web no notebook

# %%
#Coletar uma página usando HTTP GET ((COD 200 = ok))

init = "https://pt.wikipedia.org/wiki/Intelig%C3%AAncia_artificial"
response = requests.get(init)
response
# Out:
# <Response [200]>

# %%
#Atributo `text`: conteúdo da página
html = response.text
html
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="pt" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Inteligência artificial – Wikipédia, a enciclopédia livre</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":[",\\t.","\xa0\\t,"],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","janeiro","fevereiro","março","abril","maio","junho","julho","agosto","setembro","outubro","novembro","dezembro"],"wgRequestId":"YBLElNSlSKRXId2uSiHFagAAABg","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Inteligência_artificial","wgTitle":"Inteligência artificial","wgCurRevisionId":59975375,"wgRevisionId":59975375,"wgArticleId":12722,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["!CS1 manut: Nomes múltiplos: lista de autores","!CS1 inglês-fontes em língua (en)","!Artigos destacados na
# ...

# %%
bs = BeautifulSoup(html, 'html.parser')
bs
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="pt">
# <head>
# <meta charset="utf-8"/>
# <title>Inteligência artificial – Wikipédia, a enciclopédia livre</title>
# ...

# %%
#para trazer os links da pagina
links = bs('a')
links
# Out:
# [<a id="top"></a>,
#  <a class="mw-jump-link" href="#mw-head">Saltar para a navegação</a>,
#  <a class="mw-jump-link" href="#searchInput">Saltar para a pesquisa</a>,
#  <a href="/wiki/A.I._-_Intelig%C3%AAncia_Artificial" title="A.I. - Inteligência Artificial">A.I. - Inteligência Artificial</a>,
#  <a class="image" href="/wiki/Ficheiro:Nuvola_apps_kalzium.svg"><img alt="Nuvola apps kalzium.svg" data-file-height="128" data-file-width="128" decoding="async" height="20" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/8b/Nuvola_apps_kalzium.svg/20px-Nuvola_apps_kalzium.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/8b/Nuvola_apps_kalzium.svg/30px-Nuvola_apps_kalzium.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/8b/Nuvola_apps_kalzium.svg/40px-Nuvola_apps_kalzium.svg.png 2x" width="20"/></a>,
#  <a href="/wiki/Ci%C3%AAncia" title="Ciência">Ciência</a>,
#  <a href="/wiki/Ci%C3%AAncia_f%C3%ADsica" title="Ciência física">Ciências físicas</a>,
# ...

# %%
#pegar somente os links agora
hrefs = [l.get('href') for l in links]
hrefs
# Out:
# [None,
#  '#mw-head',
#  '#searchInput',
#  '/wiki/A.I._-_Intelig%C3%AAncia_Artificial',
#  '/wiki/Ficheiro:Nuvola_apps_kalzium.svg',
#  '/wiki/Ci%C3%AAncia',
#  '/wiki/Ci%C3%AAncia_f%C3%ADsica',
#  '/wiki/F%C3%ADsica',
#  '/wiki/F%C3%ADsica_moderna',
#  '/wiki/F%C3%ADsica_aplicada',
#  '/wiki/F%C3%ADsica_computacional',
#  '/wiki/F%C3%ADsica_at%C3%B3mica',
#  '/wiki/F%C3%ADsica_nuclear',
#  '/wiki/F%C3%ADsica_de_part%C3%ADculas',
#  '/wiki/F%C3%ADsica_experimental',
#  '/wiki/F%C3%ADsica_te%C3%B3rica',
#  '/wiki/F%C3%ADsica_da_mat%C3%A9ria_condensada',
#  '/wiki/Mec%C3%A2nica',
#  '/wiki/Mec%C3%A2nica_cl%C3%A1ssica',
#  '/wiki/Mec%C3%A2nica_qu%C3%A2ntica',
#  '/wiki/Introdu%C3%A7%C3%A3o_%C3%A0_mec%C3%A2nica_qu%C3%A2ntica',
#  '/wiki/Mec%C3%A2nica_de_meios_cont%C3%ADnuos',
#  '/wiki/Reologia',
#  '/wiki/Mec%C3%A2nica_dos_s%C3%B3lidos',
#  '/wiki/Mec%C3%A2nica_dos_fluidos',
#  '/wiki/Plasma',
#  '/wiki/Termodin%C3%A2mica',
#  '/wiki/Relatividade_geral',
# ...

# %%
def crawler(buscar, buscados, stop = 1):
  print('Função do crawler')
  

crawler(set([]), set([]))
# Out:
# Função do crawler

# %%
def crawler(buscar, buscados, stop = 1):
  if buscar and len(buscados) < stop:
    print('Buscar Pagina')

init = "https://pt.wikipedia.org/wiki/Intelig%C3%AAncia_artificial"
buscar = [init]
buscados = []

crawler(set(buscar), set(buscados))
# Out:
# Buscar Pagina

# %%
def crawler(buscar, buscados, stop = 1):
  if buscar and len(buscados) < stop:
    link = buscar.pop()
    print('Buscar Pagina', link)

init = "https://pt.wikipedia.org/wiki/Intelig%C3%AAncia_artificial"
buscar = [init]
buscados = []

crawler(set(buscar), set(buscados), 10)
# Out:
# Buscar Pagina https://pt.wikipedia.org/wiki/Intelig%C3%AAncia_artificial

# %%
import requests
caminho_base = '/content/drive/MyDrive/MBA/Web Mining e Social Network Analysis/aula'

def salva_arquivo(pasta. nome, conteudo):
  with open(f'{pasta}/{nome}', 'w', encoding='utf8') as arq:
    #bloco de execução enquanto o arquivo está aberto
    arq.write(conteudo)

def crawler(buscar, buscados, stop = 1):
  if buscar and len(buscados) < stop:
    link = buscar.pop()
    if link not in buscados:
      response = requests.get(link)
      print(response.text)  

init = "https://pt.wikipedia.org/wiki/Intelig%C3%AAncia_artificial"
buscar = [init]
buscados = []

crawler(set(buscar), set(buscados), 10)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="pt" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Inteligência artificial – Wikipédia, a enciclopédia livre</title>
# ...

# %%
import requests
import os
caminho_base = '/content/drive/MyDrive/MBA/Web Mining e Social Network Analysis/aula'

def salva_arquivo(pasta, nome, conteudo):

  if not os.path.isdir(pasta):
    os.makedirs(pasta, exist_ok=True)

  with open(f'{pasta}/{nome}', 'w', encoding='utf8') as arq:
    #bloco de execução enquanto o arquivo está aberto
    arq.write(conteudo)

def crawler(buscar, buscados, stop = 1):
  if buscar and len(buscados) < stop:
    link = buscar.pop()
    if link not in buscados:
      response = requests.get(link)
      salva_arquivo(f'{caminho_base}/wiki', f'wiki{len(buscados)+1}.txt', response.text) 

init = "https://pt.wikipedia.org/wiki/Intelig%C3%AAncia_artificial"
buscar = [init]
buscados = []

crawler(set([init]), set([]), 5)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-17-9e85d4cbac6c> in <module>()
#      23 buscados = []
#      24
# ---> 25 crawler(set([init]), set([]), 5)
#
# <ipython-input-17-9e85d4cbac6c> in crawler(buscar, buscados, stop)
#      17     if link not in buscados:
#      18       response = requests.get(link)
# ---> 19       salva_arquivo(f'{caminho_base}/wiki', f'wiki{len(buscados)+1}.txt', response.text)
#      20
#      21 init = "https://pt.wikipedia.org/wiki/Intelig%C3%AAncia_artificial"
#
# <ipython-input-17-9e85d4cbac6c> in salva_arquivo(pasta, nome, conteudo)
#       6
#       7   if not os.path.isdir(pasta):
# ----> 8     os.makedirs(pasta, exist_ok=True)
#       9
#      10   with open(f'{pasta}/{nome}', 'w', encoding='utf8') as arq:
#
# /usr/lib/python3.6/os.py in makedirs(name, mode, exist_ok)
#     218             return
#     219     try:
# ...
