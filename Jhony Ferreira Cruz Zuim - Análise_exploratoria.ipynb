# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-09d1e7ea-996e-4856-8c3f-6390f02297a9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-09d1e7ea-996e-4856-8c3f-6390f02297a9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving olist_purchases.csv to olist_purchases (1).csv

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['olist_purchases.csv']))
# Dataset is now stored in a Pandas Dataframe
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8b2b99493941> in <module>()
#       1 import io
# ----> 2 df = pd.read_csv(io.BytesIO(uploaded['olist_purchases.csv']))
#       3 # Dataset is now stored in a Pandas Dataframe
#
# NameError: name 'uploaded' is not defined

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
df2=pd.read_csv('/content/drive/MyDrive/olist_purchases.csv')

# %%
df=df2[:1000]

# %%
df.head(3)
# Out:
#    Unnamed: 0                       customer_id  \
# 0           0  06b8999e2fba1a1fbc88172c00ba8bc7
# 1           1  18955e83d337fd6b2def6b18a428ac77
# 2           2  4e7b3e00288586ebd08712fdd0374a03
#
#                  customer_unique_id  customer_zip_code_prefix  \
# 0  861eff4711a542e4b93843c6dd7febb0                     14409
# 1  290c77bc529b7ac935b93aa66c333dc3                      9790
# 2  060e732b5b29e8181a18229c7b0b2b5e                      1151
#
#            customer_city customer_state                          order_id  \
# 0                 franca             SP  00e7ee1b050b8499577073aeb2a297a1
# 1  sao bernardo do campo             SP  29150127e6685892b6eab3eec79f59c7
# 2              sao paulo             SP  b2059ed67ce144a36e2aa97d2c9e9ad2
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-05-16 15:05:35  2017-05-16 15:22:12
# 1    delivered      2018-01-12 20:48:24  2018-01-12 20:58:32
# ...

# %%
df.tail(10)
# Out:
#      Unnamed: 0                       customer_id  \
# 990         990  8bfde2e8ee1c470784cebf3888dc3368
# 991         991  25d0a19994db670da25c2a23de8466f0
# 992         992  62e4c45005f78e9efce8f9b361151a04
# 993         993  bfc0d6ebdaec3937d7dffc39fa93fb91
# 994         994  bfc0d6ebdaec3937d7dffc39fa93fb91
# 995         995  50111fb86c6159052296bbf2598ef7ee
# 996         996  8310c27f705802263986d24aa21bf014
# 997         997  0f0242e95194275e6fcb0660f728b7c3
# 998         998  04361b218639fa1eea85ab84aebcab7f
# 999         999  deaca55a21b9248b34e823583f5ddf34
#
#                    customer_unique_id  customer_zip_code_prefix  \
# 990  827af9fc3113e6e7b0cdc85dea8fa44b                     24358
# 991  f820eddce0a5ff03e1e40168b5ddb0ec                     22460
# 992  7f8332909b975683069ed4777867f021                     74973
# 993  bd8e0f3ea9fb694fc53c7a358643fc06                     74435
# 994  bd8e0f3ea9fb694fc53c7a358643fc06                     74435
# ...

# %%
df.shape
# Out:
# (1000, 29)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     1000 non-null   int64
#  1   customer_id                    1000 non-null   object
#  2   customer_unique_id             1000 non-null   object
#  3   customer_zip_code_prefix       1000 non-null   int64
#  4   customer_city                  1000 non-null   object
#  5   customer_state                 1000 non-null   object
#  6   order_id                       1000 non-null   object
#  7   order_status                   1000 non-null   object
#  8   order_purchase_timestamp       1000 non-null   object
#  9   order_approved_at              1000 non-null   object
#  10  order_delivered_carrier_date   988 non-null    object
#  11  order_delivered_customer_date  973 non-null    object
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'customer_id', 'customer_unique_id',
#        'customer_zip_code_prefix', 'customer_city', 'customer_state',
#        'order_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date',
#        'order_item_id', 'product_id', 'seller_id', 'shipping_limit_date',
#        'price', 'freight_value', 'payment_sequential', 'payment_type',
#        'payment_installments', 'payment_value', 'review_id', 'review_score',
#        'review_comment_title', 'review_comment_message',
#        'review_creation_date', 'review_answer_timestamp'],
#       dtype='object')

# %%
df.describe()
# Out:
#         Unnamed: 0  customer_zip_code_prefix  order_item_id        price  \
# count  1000.000000               1000.000000     1000.00000  1000.000000
# mean    499.500000              33832.464000        1.15700   113.152320
# std     288.819436              29747.740599        0.48434   151.255682
# min       0.000000               1008.000000        1.00000     3.490000
# 25%     249.750000               9759.500000        1.00000    39.900000
# 50%     499.500000              23450.000000        1.00000    69.900000
# 75%     749.250000              55535.000000        1.00000   134.992500
# max     999.000000              99200.000000        5.00000  1899.000000
#
#        freight_value  payment_sequential  payment_installments  payment_value  \
# count    1000.000000         1000.000000            1000.00000     1000.00000
# mean       18.459650            1.055000               2.93600      152.09267
# ...

# %%
df.head()
# Out:
#    Unnamed: 0                       customer_id  \
# 0           0  06b8999e2fba1a1fbc88172c00ba8bc7
# 1           1  18955e83d337fd6b2def6b18a428ac77
# 2           2  4e7b3e00288586ebd08712fdd0374a03
# 3           3  b2b6027bc5c5109e529d4dc6358b12c3
# 4           4  4f2d8ab171c80ec8364f7c12e35b23ad
#
#                  customer_unique_id  customer_zip_code_prefix  \
# 0  861eff4711a542e4b93843c6dd7febb0                     14409
# 1  290c77bc529b7ac935b93aa66c333dc3                      9790
# 2  060e732b5b29e8181a18229c7b0b2b5e                      1151
# 3  259dac757896d24d7702b9acbbff3f3c                      8775
# 4  345ecd01c38d18a9036ed96c73b8d066                     13056
#
#            customer_city customer_state                          order_id  \
# 0                 franca             SP  00e7ee1b050b8499577073aeb2a297a1
# 1  sao bernardo do campo             SP  29150127e6685892b6eab3eec79f59c7
# ...

# %%
df=df[['customer_id', 
       'customer_zip_code_prefix', 'customer_city', 'customer_state',
       'order_id', 'order_status', 'order_purchase_timestamp',
       'order_item_id', 'product_id', 'seller_id', 'shipping_limit_date',
       'price', 'freight_value',  'payment_type',
        'payment_value', 'review_score',
       'review_comment_title', 'review_comment_message',
       'review_creation_date', 'review_answer_timestamp']]

# %%
df.head()
# Out:
#                         customer_id  customer_zip_code_prefix  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7                     14409
# 1  18955e83d337fd6b2def6b18a428ac77                      9790
# 2  4e7b3e00288586ebd08712fdd0374a03                      1151
# 3  b2b6027bc5c5109e529d4dc6358b12c3                      8775
# 4  4f2d8ab171c80ec8364f7c12e35b23ad                     13056
#
#            customer_city customer_state                          order_id  \
# 0                 franca             SP  00e7ee1b050b8499577073aeb2a297a1
# 1  sao bernardo do campo             SP  29150127e6685892b6eab3eec79f59c7
# 2              sao paulo             SP  b2059ed67ce144a36e2aa97d2c9e9ad2
# 3        mogi das cruzes             SP  951670f92359f4fe4a63112aa7306eba
# 4               campinas             SP  6b7d50bd145f6fc7f33cebabd7e49d0f
#
#   order_status order_purchase_timestamp  order_item_id  \
# 0    delivered      2017-05-16 15:05:35            1.0
# ...

# %%
df['order_status'].unique()
# Out:
# array(['delivered', 'invoiced', 'shipped', 'processing', 'canceled'],
#       dtype=object)

# %%
df['order_status'].value_counts()
# Out:
# delivered     973
# shipped        15
# invoiced        8
# canceled        3
# processing      1
# Name: order_status, dtype: int64

# %%
df['order_status'].value_counts(normalize=True)
# Out:
# delivered     0.973
# shipped       0.015
# invoiced      0.008
# canceled      0.003
# processing    0.001
# Name: order_status, dtype: float64

# %%
df['review_comment_title'].value_counts(dropna=False)
# Out:
# NaN                         883
# QUANTIDADE ERRADA             5
# Recomendo                     5
# recomendo                     5
# Otimo                         4
#                            ...
# Excelente parceiro            1
# adorei                        1
# Nada de produto               1
# Recebi pedido incompleto      1
# Não posso avaliar ainda       1
# Name: review_comment_title, Length: 84, dtype: int64

# %%
df['review_comment_title'].value_counts()
# Out:
# Recomendo                   5
# QUANTIDADE ERRADA           5
# recomendo                   5
# Não recebi meu produto      4
# Otimo                       4
#                            ..
# adorei                      1
# Nada de produto             1
# Recebi pedido incompleto    1
# Gostei muito do produto     1
# Produto não foi entregue    1
# Name: review_comment_title, Length: 83, dtype: int64

# %%
df['customer_state'].value_counts()
# Out:
# SP    435
# RJ    143
# MG    110
# RS     51
# PR     51
# SC     34
# BA     27
# GO     26
# DF     23
# ES     22
# PE     19
# CE     11
# MS     10
# MT      9
# PA      5
# PI      4
# RN      4
# AL      4
# MA      4
# RO      2
# PB      2
# AC      1
# AM      1
# TO      1
# AP      1
# Name: customer_state, dtype: int64

# %%
df_sp=df[df['customer_state']=='SP']

# %%
df_sp
# Out:
#                           customer_id  customer_zip_code_prefix  \
# 0    06b8999e2fba1a1fbc88172c00ba8bc7                     14409
# 1    18955e83d337fd6b2def6b18a428ac77                      9790
# 2    4e7b3e00288586ebd08712fdd0374a03                      1151
# 3    b2b6027bc5c5109e529d4dc6358b12c3                      8775
# 4    4f2d8ab171c80ec8364f7c12e35b23ad                     13056
# ..                                ...                       ...
# 979  dd8fd4a958c49d92d56c854065d11234                      8536
# 980  690f9f1b864ed6712a50a3d444c224a0                     12215
# 983  ff4ead15d934b5b5896ca73904d07f66                      6786
# 988  388a43487598d630805ec56499bc6ddb                      7080
# 995  50111fb86c6159052296bbf2598ef7ee                      6270
#
#              customer_city customer_state                          order_id  \
# 0                   franca             SP  00e7ee1b050b8499577073aeb2a297a1
# ...

# %%
df_sp_osasco=df_sp[df_sp['customer_city']=='osasco']
df_sp_guarulhos=df_sp[df_sp['customer_city']=='guarulhos']

# %%
df_sp_osasco
# Out:
#                           customer_id  customer_zip_code_prefix customer_city  \
# 224  e4dbb700c76f5706dd58f9b9ef613aed                      6290        osasco
# 517  be5a493a772f5d77e1a9ef3b791176d2                      6286        osasco
# 626  a86314eff3e69dc24f43d56010778157                      6140        osasco
# 627  a86314eff3e69dc24f43d56010778157                      6140        osasco
# 628  a86314eff3e69dc24f43d56010778157                      6140        osasco
# 629  a86314eff3e69dc24f43d56010778157                      6140        osasco
# 630  a86314eff3e69dc24f43d56010778157                      6140        osasco
# 631  ce303f783b5f596243cf7100d6b848a6                      6056        osasco
# 662  05425c98e35d762211742df2a2b30af0                      6114        osasco
# 883  b477418308092b09b13af032ca19cc52                      6283        osasco
# 995  50111fb86c6159052296bbf2598ef7ee                      6270        osasco
#
# ...

# %%
df_sp_guarulhos
# Out:
#                           customer_id  customer_zip_code_prefix customer_city  \
# 17   c5c61596a3b6bd0cee5766992c48a9a1                      7124     guarulhos
# 41   41c8f4b570869791379a925899a6af8a                      7170     guarulhos
# 45   4a0e66fd30684aa1409cd1b66fec77cc                      7176     guarulhos
# 48   0ccd415657ae8a6cd1c71b00155a019e                      7053     guarulhos
# 154  faafae37ddb3e4af81c10a397bcca35f                      7243     guarulhos
# 237  80c74074b2a3c419ee813c0b31ef95c7                      7191     guarulhos
# 342  b09ff235742f48bfa743f3e9474d36ef                      7197     guarulhos
# 414  620c2e659b5d119813362bfe4bbe8634                      7251     guarulhos
# 459  8ac977b83cae48a1d1216f13b06aaa2c                      7020     guarulhos
# 460  8ac977b83cae48a1d1216f13b06aaa2c                      7020     guarulhos
# 594  0eed1698388ba8c1fe0efa37ba6f269d                      7143     guarulhos
# ...

# %%
df_sp_osasco['order_status'].value_counts()
# Out:
# delivered    11
# Name: order_status, dtype: int64

# %%
df_sp_osasco['review_score'].hist()

# %%
plt.style.use('ggplot')
df_sp_osasco['order_status'].hist()

# %%
df_sp['review_score'].plot.kde()

# %%
df_sp['review_score'].plot.density()

# %%
corr=df.corr()

# %%
corr
# Out:
#                           customer_zip_code_prefix  order_item_id     price  \
# customer_zip_code_prefix                  1.000000      -0.056616 -0.017869
# order_item_id                            -0.056616       1.000000 -0.095875
# price                                    -0.017869      -0.095875  1.000000
# freight_value                             0.253897      -0.050139  0.278657
# payment_value                            -0.045808       0.178923  0.867758
# review_score                             -0.074553      -0.079881 -0.006600
#
#                           freight_value  payment_value  review_score
# customer_zip_code_prefix       0.253897      -0.045808     -0.074553
# order_item_id                 -0.050139       0.178923     -0.079881
# price                          0.278657       0.867758     -0.006600
# freight_value                  1.000000       0.287937     -0.043809
# payment_value                  0.287937       1.000000     -0.003287
# ...

# %%
sns.heatmap(corr)

# %%
sns.boxplot(x=df['payment_value'],y=df['review_score'])

# %%
df.head()
# Out:
#                         customer_id  customer_zip_code_prefix  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7                     14409
# 1  18955e83d337fd6b2def6b18a428ac77                      9790
# 2  4e7b3e00288586ebd08712fdd0374a03                      1151
# 3  b2b6027bc5c5109e529d4dc6358b12c3                      8775
# 4  4f2d8ab171c80ec8364f7c12e35b23ad                     13056
#
#            customer_city customer_state                          order_id  \
# 0                 franca             SP  00e7ee1b050b8499577073aeb2a297a1
# 1  sao bernardo do campo             SP  29150127e6685892b6eab3eec79f59c7
# 2              sao paulo             SP  b2059ed67ce144a36e2aa97d2c9e9ad2
# 3        mogi das cruzes             SP  951670f92359f4fe4a63112aa7306eba
# 4               campinas             SP  6b7d50bd145f6fc7f33cebabd7e49d0f
#
#   order_status order_purchase_timestamp  order_item_id  \
# 0    delivered      2017-05-16 15:05:35            1.0
# ...

# %%
# !pip install datatime

# %%
import datetime
from datetime import datetime

# %%
df['datetime']=df['order_purchase_timestamp'].apply(lambda row : datetime.strptime(str(row),'%Y-%m-%d %H:%M:%S'))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['weekday']=df['datetime'].apply(lambda row: row.weekday())
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['dayhour']=df['datetime'].apply(lambda row: row.hour)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['dayhour']
# Out:
# 0      15
# 1      20
# 2      16
# 3      16
# 4       9
#        ..
# 995    18
# 996     9
# 997    18
# 998    19
# 999    10
# Name: dayhour, Length: 1000, dtype: int64

# %%
sns.pairplot(df)

# %%
df_sp_guarulhos['weekday'].hist(bins=7)

# %%
df_sp['weekday'].value_counts()
# Out:
# 1    76
# 2    74
# 0    72
# 3    62
# 4    61
# 6    55
# 5    35
# Name: weekday, dtype: int64

# %%
df_sp_guarulhos['dayhour'].hist(bins=24)
